# %% [markdown]
# # Batch 2 — Pre-Scan Summary

# %%
import pandas as pd
from pathlib import Path
csv_path = Path(r'../data/batch2_pre_scan_summary.csv').resolve()
df = pd.read_csv(csv_path)
df
# Out:
#               filename     sex  reference_image  sample_area_cm2  \
# 0  B2_M_0 Pre-Scan.txt    Male  B2_M_0 Pre-Scan           27.828
# 1  B2_M_1 Pre-Scan.txt    Male  B2_M_1 Pre-Scan           30.886
# 2  B2_M_2 Pre-Scan.txt    Male  B2_M_2 Pre-Scan           31.799
# 3  B2_M_3 Pre-Scan.txt    Male  B2_M_3 Pre-Scan           31.313
# 4  B2_M_4 Pre-Scan.txt    Male  B2_M_4 Pre-Scan           30.196
# 5  B2_F_0 Pre-Scan.txt  Female  B2_F_0 Pre-Scan           27.093
# 6  B2_F_1 Pre-Scan.txt  Female  B2_F_1 Pre-Scan           28.961
# 7  B2_F_2 Pre-Scan.txt  Female  B2_F_2 Pre-Scan           27.508
# 8  B2_F_3 Pre-Scan.txt  Female  B2_F_3 Pre-Scan           30.672
# 9  B2_F_4 Pre-Scan.txt  Female  B2_F_4 Pre-Scan           29.730
#
#    bone_area_cm2  total_weight_g  soft_weight_g  lean_weight_g  fat_weight_g  \
# 0          9.212         26.4998        25.8247        19.2367        6.5880
# 1          9.327         30.3463        29.6736        21.8478        7.8258
# 2          9.308         30.0257        29.3620        19.8097        9.5523
# 3          9.061         31.0387        30.3784        20.1089       10.2695
# 4          8.870         29.3860        28.7646        21.3238        7.4408
# 5          7.963         22.5412        22.0361        13.2859        8.7502
# 6          9.370         27.7358        27.0752        16.4204       10.6548
# 7          9.268         26.2425        25.6099        14.3603       11.2496
# 8          9.243         28.7504        28.1500        16.4967       11.6533
# 9          8.999         27.6755        27.0616        16.5638       10.4978
#
#    fat_percent    BMC_g  BMD_mg_per_cm2
# 0       25.510  0.67514          73.286
# 1       26.373  0.67271          72.125
# 2       32.533  0.66367          71.304
# 3       33.805  0.66028          72.873
# 4       25.868  0.62137          70.056
# 5       39.708  0.50510          63.429
# 6       39.353  0.66057          70.499
# 7       43.927  0.63265          68.258
# 8       41.397  0.60035          64.950
# 9       38.792  0.61393          68.220

# %% [markdown]
# ## Batch 2 — 1-week post-treatment summary
#
# This cell displays a table built from any "1 week" or "1-week post-treatment" TXT reports found under the Batch 2 folder.

# %%
# Robust search for any "week 1" or "week1" TXT files and extract INSIDE ROI + WHOLE TISSUE stats
from pathlib import Path
import re

batch_dir = Path(r"c:\Users\hanss\Downloads\DEXA Scans (1)\DEXA Scans\Batch 2")
patterns = {
    'sample_area': re.compile(r"Sample Area:\s*([0-9.]+)\s*cm\^2"),
    'bone_area': re.compile(r"Bone Area:\s*([0-9.]+)\s*cm\^2"),
    'total_weight': re.compile(r"Total Weight:\s*([0-9.]+)\s*g"),
    'soft_weight': re.compile(r"Soft Weight:\s*([0-9.]+)\s*g"),
    'lean_weight': re.compile(r"Lean Weight:\s*([0-9.]+)\s*g"),
    'fat_weight': re.compile(r"Fat Weight:\s*([0-9.]+)\s*g"),
    'fat_percent': re.compile(r"Fat Percent:\s*([0-9.]+)"),
    'BMC': re.compile(r"BMC:\s*([0-9.]+)\s*g"),
    'BMD': re.compile(r"BMD:\s*([0-9.]+)\s*mg/cm\^2"),
}

week_tokens = ['week1','wk1','1 week','1-week','week 1','week_1','week-1']
rows = []
for txt in batch_dir.rglob('*.txt'):
    nl = str(txt).lower()
    if any(tok in nl for tok in week_tokens) or ('week' in nl and '1' in nl) or ('post' in nl and '1' in nl):
        text = txt.read_text(encoding='utf-8', errors='replace')
        # isolate sections if present
        inside_block = ''
        whole_block = ''
        if 'INSIDE ROI TISSUE STATISTICS:' in text and 'WHOLE TISSUE STATISTICS:' in text:
            inside_block = text.split('INSIDE ROI TISSUE STATISTICS:')[1].split('WHOLE TISSUE STATISTICS:')[0]
            whole_block = text.split('WHOLE TISSUE STATISTICS:')[1]
        else:
            inside_block = text
        row = {
            'batch': batch_dir.name,
            'filename': txt.name,
            'path': str(txt)
        }
        for k,p in patterns.items():
            mi = p.search(inside_block)
            mw = p.search(whole_block)
            row[f'inside_{k}'] = mi.group(1) if mi else ''
            row[f'whole_{k}'] = mw.group(1) if mw else ''
        rows.append(row)

try:
    import pandas as pd
    if rows:
        df = pd.DataFrame(rows)
        display(df.sort_values('filename').reset_index(drop=True))
    else:
        print('No week-1 TXT files found under', batch_dir)
except Exception as e:
    print('Parsed rows:', len(rows), ' — pandas not available. Error:', e)
    for r in rows:
        print(r)
# Out:
#       batch           filename  \
# 0   Batch 2  B2_F_0 Retake.txt
# 1   Batch 2         B2_F_0.txt
# 2   Batch 2         B2_F_0.txt
# 3   Batch 2         B2_F_0.txt
# 4   Batch 2         B2_F_0.txt
# 5   Batch 2         B2_F_1.txt
# 6   Batch 2         B2_F_1.txt
# 7   Batch 2         B2_F_1.txt
# 8   Batch 2         B2_F_1.txt
# 9   Batch 2         B2_F_2.txt
# 10  Batch 2         B2_F_2.txt
# 11  Batch 2         B2_F_2.txt
# 12  Batch 2         B2_F_2.txt
# 13  Batch 2         B2_F_3.txt
# 14  Batch 2         B2_F_3.txt
# 15  Batch 2         B2_F_4.txt
# 16  Batch 2         B2_F_4.txt
# 17  Batch 2         B2_F_4.txt
# 18  Batch 2         B2_F_4.txt
# 19  Batch 2         B2_M_0.txt
# 20  Batch 2         B2_M_0.txt
# 21  Batch 2         B2_M_0.txt
# 22  Batch 2         B2_M_0.txt
# 23  Batch 2  B2_M_1 Retake.txt
# 24  Batch 2         B2_M_1.txt
# 25  Batch 2         B2_M_1.txt
# 26  Batch 2         B2_M_1.txt
# 27  Batch 2         B2_M_1.txt
# 28  Batch 2         B2_M_2.txt
# 29  Batch 2         B2_M_2.txt
# 30  Batch 2         B2_M_2.txt
# 31  Batch 2         B2_M_3.txt
# 32  Batch 2         B2_M_3.txt
# 33  Batch 2         B2_M_3.txt
# 34  Batch 2         B2_M_3.txt
# 35  Batch 2         B2_M_4.txt
# 36  Batch 2         B2_M_4.txt
# 37  Batch 2         B2_M_4.txt
# 38  Batch 2         B2_M_4.txt
# 39  Batch 2         B2_m_2.txt
#
#                                                  path inside_sample_area  \
# 0   c:\Users\hanss\Downloads\DEXA Scans (1)\DEXA S...             23.986
# 1   c:\Users\hanss\Downloads\DEXA Scans (1)\DEXA S...             27.050
# 2   c:\Users\hanss\Downloads\DEXA Scans (1)\DEXA S...             25.795
# 3   c:\Users\hanss\Downloads\DEXA Scans (1)\DEXA S...             27.197
# 4   c:\Users\hanss\Downloads\DEXA Scans (1)\DEXA S...             27.736
# 5   c:\Users\hanss\Downloads\DEXA Scans (1)\DEXA S...             30.547
# 6   c:\Users\hanss\Downloads\DEXA Scans (1)\DEXA S...             30.370
# 7   c:\Users\hanss\Downloads\DEXA Scans (1)\DEXA S...             31.724
# 8   c:\Users\hanss\Downloads\DEXA Scans (1)\DEXA S...             30.476
# 9   c:\Users\hanss\Downloads\DEXA Scans (1)\DEXA S...             30.843
# 10  c:\Users\hanss\Downloads\DEXA Scans (1)\DEXA S...             30.036
# 11  c:\Users\hanss\Downloads\DEXA Scans (1)\DEXA S...             29.365
# 12  c:\Users\hanss\Downloads\DEXA Scans (1)\DEXA S...             29.205
# 13  c:\Users\hanss\Downloads\DEXA Scans (1)\DEXA S...             23.334
# 14  c:\Users\hanss\Downloads\DEXA Scans (1)\DEXA S...             28.505
# 15  c:\Users\hanss\Downloads\DEXA Scans (1)\DEXA S...             30.408
# 16  c:\Users\hanss\Downloads\DEXA Scans (1)\DEXA S...             29.653
# 17  c:\Users\hanss\Downloads\DEXA Scans (1)\DEXA S...             29.865
# 18  c:\Users\hanss\Downloads\DEXA Scans (1)\DEXA S...             29.380
# 19  c:\Users\hanss\Downloads\DEXA Scans (1)\DEXA S...             29.018
# 20  c:\Users\hanss\Downloads\DEXA Scans (1)\DEXA S...             29.695
# 21  c:\Users\hanss\Downloads\DEXA Scans (1)\DEXA S...             28.796
# 22  c:\Users\hanss\Downloads\DEXA Scans (1)\DEXA S...             29.459
# 23  c:\Users\hanss\Downloads\DEXA Scans (1)\DEXA S...             29.942
# 24  c:\Users\hanss\Downloads\DEXA Scans (1)\DEXA S...             30.592
# 25  c:\Users\hanss\Downloads\DEXA Scans (1)\DEXA S...             30.265
# 26  c:\Users\hanss\Downloads\DEXA Scans (1)\DEXA S...             31.421
# 27  c:\Users\hanss\Downloads\DEXA Scans (1)\DEXA S...             29.852
# 28  c:\Users\hanss\Downloads\DEXA Scans (1)\DEXA S...             29.901
# 29  c:\Users\hanss\Downloads\DEXA Scans (1)\DEXA S...             30.322
# 30  c:\Users\hanss\Downloads\DEXA Scans (1)\DEXA S...             30.548
# 31  c:\Users\hanss\Downloads\DEXA Scans (1)\DEXA S...             29.682
# 32  c:\Users\hanss\Downloads\DEXA Scans (1)\DEXA S...             30.409
# 33  c:\Users\hanss\Downloads\DEXA Scans (1)\DEXA S...             31.197
# 34  c:\Users\hanss\Downloads\DEXA Scans (1)\DEXA S...             29.667
# 35  c:\Users\hanss\Downloads\DEXA Scans (1)\DEXA S...             27.218
# 36  c:\Users\hanss\Downloads\DEXA Scans (1)\DEXA S...             27.668
# 37  c:\Users\hanss\Downloads\DEXA Scans (1)\DEXA S...             28.142
# 38  c:\Users\hanss\Downloads\DEXA Scans (1)\DEXA S...             27.899
# 39  c:\Users\hanss\Downloads\DEXA Scans (1)\DEXA S...             29.255
#
#    whole_sample_area inside_bone_area whole_bone_area inside_total_weight  \
# 0             25.934            9.567          10.570             23.0579
# 1             27.786            8.711           8.953             24.6231
# 2             25.858            7.677           7.709             24.0544
# 3             30.048           10.930          12.596             23.6082
# 4             29.971            8.836           9.948             25.0474
# 5             32.821            9.499          10.754             30.0952
# 6             32.641            9.148          10.347             31.1340
# 7             33.039            9.095           9.468             30.4185
# 8             31.203            9.302           9.513             30.3301
# 9             33.054            9.866          11.016             28.2489
# 10            31.103            9.140           9.435             27.5639
# 11            29.925            9.098           9.248             27.1932
# 12            31.574            9.193          10.411             28.0153
# 13            26.209            7.471           9.231             26.2235
# 14            29.224            8.787           9.116             28.3986
# 15            31.037            9.542           9.704             30.0500
# 16            32.327            9.091          10.467             30.2763
# 17            32.948            9.574          11.165             29.7573
# 18            31.558            9.724           9.923             28.4249
# 19            32.241            9.564          11.354             29.9928
# 20            32.020            9.852          11.175             29.9673
# 21            29.452            8.514           8.670             30.6141
# 22            29.723            9.247           9.359             29.5626
# 23            32.325            9.897          11.003             31.8067
# 24            30.989            9.114           9.222             32.0475
# 25            33.199           10.617          12.157             32.6117
# 26            34.340            9.544          11.052             32.3164
# 27            31.104            9.304           9.524             31.5554
# 28            32.738            8.198           9.640             31.0176
# 29            30.519            8.197           8.243             29.7967
# 30            31.493            9.019           9.317             31.8098
# 31            32.091            9.604          10.013             30.4109
# 32            33.353            8.703          10.015             30.8093
# 33            31.197            8.858           8.858             32.2576
# 34            32.817            9.160          10.780             31.5492
# 35            28.313            8.438           8.614             28.7158
# 36            28.581            8.831           9.086             28.0062
# 37            31.037            8.676          10.162             28.4131
# 38            30.214            8.655           9.581             29.1770
# 39            32.287            8.522          10.159             30.5778
#
#    whole_total_weight inside_soft_weight  ... inside_lean_weight  \
# 0             24.9591            22.2724  ...            13.4317
# 1             25.4822            24.0002  ...            15.6430
# 2             24.1355            23.5507  ...            16.1780
# 3             26.5379            22.6392  ...            11.3408
# 4             27.1984            24.3587  ...            16.4951
# 5             32.5069            29.3772  ...            18.1972
# 6             33.5920            30.4848  ...            20.6420
# 7             31.7259            29.7811  ...            19.8027
# 8             31.0961            29.6523  ...            19.3945
# 9             30.5946            27.5920  ...            16.4012
# 10            28.5957            26.9643  ...            16.2166
# 11            27.7327            26.5851  ...            16.1146
# 12            30.5018            27.3997  ...            17.1321
# 13            29.9516            25.7035  ...            17.1651
# 14            29.2530            27.8391  ...            17.1961
# 15            30.6670            29.3578  ...            17.1337
# 16            33.1094            29.6181  ...            17.7406
# 17            33.1033            29.0573  ...            16.3480
# 18            30.7161            27.7230  ...            14.4506
# 19            33.6346            29.1841  ...            22.9798
# 20            32.6761            29.1080  ...            22.4777
# 21            31.2881            29.9465  ...            22.2300
# 22            29.8956            28.8609  ...            21.8735
# 23            34.7070            30.9429  ...            22.4030
# 24            32.5817            31.3771  ...            22.6546
# 25            35.9422            31.6393  ...            21.5539
# 26            35.5604            31.5440  ...            24.3881
# 27            33.0026            30.8334  ...            22.5576
# 28            34.2940            30.4477  ...            21.9741
# 29            30.0148            29.2127  ...            20.3997
# 30            32.9236            31.1494  ...            20.8754
# 31            32.6111            29.7139  ...            18.7389
# 32            33.9877            30.2116  ...            21.8501
# 33            32.2576            31.6361  ...            22.4443
# 34            35.0434            30.9031  ...            20.6945
# 35            29.8394            28.0954  ...            20.9784
# 36            29.0568            27.3592  ...            20.2348
# 37            31.7375            27.7893  ...            21.6920
# 38            31.9468            28.5498  ...            21.1971
# 39            34.2751            29.9818  ...            20.9862
#
#    whole_lean_weight inside_fat_weight whole_fat_weight inside_fat_percent  \
# 0            14.0918            8.8406           9.9242             39.693
# 1            16.0854            8.3573           8.7504             34.822
# 2            16.2253            7.3727           7.4038             31.306
# 3            11.8463           11.2984          13.4118             49.906
# 4            17.5472            7.8635           8.8165             32.282
# 5            19.1305           11.1801          12.4695             38.057
# 6            21.6707            9.8428          11.0842             32.287
# 7            20.4816            9.9784          10.5676             33.506
# 8            19.6246           10.2578          10.7690             34.593
# 9            17.2589           11.1908          12.5249             40.558
# 10           16.7334           10.7477          11.2407             39.859
# 11           16.3252           10.4705          10.7826             39.385
# 12           18.2799           10.2676          11.4427             37.474
# 13           19.2559            8.5384           9.9004             33.219
# 14           17.4924           10.6430          11.1660             38.230
# 15           17.3393           12.2241          12.6171             41.638
# 16           18.9051           11.8775          13.3456             40.102
# 17           17.6144           12.7093          14.5459             43.739
# 18           15.3962           13.2724          14.5981             47.875
# 19           25.1828            6.2042           7.3650             21.259
# 20           23.7834            6.6303           7.8042             22.778
# 21           22.7329            7.7165           7.8777             25.768
# 22           22.0509            6.9874           7.1310             24.211
# 23           23.7871            8.5399           9.8747             27.599
# 24           23.0148            8.7224           8.8882             27.799
# 25           22.9780           10.0854          11.7109             31.876
# 26           26.1773            7.1559           8.3831             22.686
# 27           23.5050            8.2757           8.7593             26.840
# 28           23.8324            8.4736           9.6847             27.830
# 29           20.5540            8.8130           8.8734             30.168
# 30           21.4527           10.2740          10.7825             32.983
# 31           19.7818           10.9749          12.0966             36.935
# 32           23.8090            8.3616           9.4026             27.677
# 33           22.4443            9.1918           9.1918             29.055
# 34           22.6185           10.2086          11.5648             33.034
# 35           21.7396            7.1170           7.4612             25.331
# 36           20.9440            7.1244           7.4438             26.040
# 37           23.7581            6.0973           7.1434             21.941
# 38           22.8221            7.3526           8.3484             25.754
# 39           22.9294            8.9956          10.4996             30.003
#
#    whole_fat_percent inside_BMC whole_BMC inside_BMD whole_BMD
# 0             41.323    0.78551   0.94307     82.105    89.224
# 1             35.233    0.62290   0.64646     71.504    72.207
# 2             31.333    0.50372   0.50644     65.610    65.693
# 3             53.099    0.96890   1.27987     88.649   101.612
# 4             33.442    0.68869   0.83464     77.942    83.900
# 5             39.460    0.71801   0.90699     75.590    84.340
# 6             33.840    0.64926   0.83717     70.973    80.906
# 7             34.035    0.63743   0.67679     70.082    71.484
# 8             35.432    0.67779   0.70251     72.862    73.848
# 9             42.053    0.65682   0.81073     66.576    73.597
# 10            40.182    0.59962   0.62168     65.601    65.893
# 11            39.777    0.60810   0.62495     66.842    67.579
# 12            38.498    0.61563   0.77923     66.971    74.844
# 13            33.956    0.51999   0.79529     69.604    86.152
# 14            38.962    0.55952   0.59456     63.676    65.225
# 15            42.118    0.69214   0.71053     72.533    73.218
# 16            41.381    0.65813   0.85871     72.394    82.037
# 17            45.229    0.70001   0.94308     73.116    84.468
# 18            48.670    0.70184   0.72181     72.174    72.744
# 19            22.628    0.80876   1.08673     84.563    95.717
# 20            24.707    0.85936   1.08854     87.225    97.408
# 21            25.735    0.66756   0.67751     78.409    78.145
# 22            24.436    0.70169   0.71372     75.885    76.265
# 23            29.335    0.86387   1.04521     87.289    94.989
# 24            27.860    0.67044   0.67872     73.558    73.599
# 25            33.760    0.97240   1.25340     91.592   103.098
# 26            24.256    0.77243   1.00002     80.936    90.482
# 27            27.149    0.72204   0.73828     77.609    77.515
# 28            28.895    0.56986   0.77687     69.512    80.591
# 29            30.154    0.58404   0.58735     71.252    71.255
# 30            33.449    0.66036   0.68840     73.216    73.889
# 31            37.946    0.69700   0.73273     72.576    73.176
# 32            28.311    0.59763   0.77598     68.672    77.480
# 33            29.055    0.62152   0.62152     70.163    70.163
# 34            33.832    0.64613   0.86014     70.535    79.793
# 35            25.551    0.62041   0.63861     73.522    74.137
# 36            26.222    0.64703   0.66897     73.272    73.625
# 37            23.117    0.62379   0.83608     71.903    82.277
# 38            26.783    0.62720   0.77628     72.468    81.019
# 39            31.409    0.59606   0.84604     69.941    83.282
#
# [40 rows x 21 columns]

# %% [markdown]
# ## Batch 2 — 2-week post-treatment summary

# %%
# Batch 2 — 2-week post-treatment summary
from pathlib import Path
import re

DATA_CSV2 = Path(r'../data/week2_reports.csv').resolve()
batch_name = 'Batch 2'

def scan_and_build_week(downloads_root, week_num):
    week_re = re.compile(rf'(?:week[\s_-]*{week_num}|{week_num}[\s_-]*week|wk[\s_-]*{week_num}|week{week_num}|{week_num}week)', re.I)
    patterns = {
        'sample_area': re.compile(r"Sample Area:\s*([0-9.]+)\s*cm\^2"),
        'bone_area': re.compile(r"Bone Area:\s*([0-9.]+)\s*cm\^2"),
        'total_weight': re.compile(r"Total Weight:\s*([0-9.]+)\s*g"),
        'soft_weight': re.compile(r"Soft Weight:\s*([0-9.]+)\s*g"),
        'lean_weight': re.compile(r"Lean Weight:\s*([0-9.]+)\s*g"),
        'fat_weight': re.compile(r"Fat Weight:\s*([0-9.]+)\s*g"),
        'fat_percent': re.compile(r"Fat Percent:\s*([0-9.]+)"),
        'BMC': re.compile(r"BMC:\s*([0-9.]+)\s*g"),
        'BMD': re.compile(r"BMD:\s*([0-9.]+)\s*mg/cm\^2"),
    }
    rows = []
    for txt in downloads_root.rglob('*.txt'):
        nl = str(txt).lower()
        if week_re.search(nl):
            text = txt.read_text(encoding='utf-8', errors='replace')
            inside_block = ''
            whole_block = ''
            if 'INSIDE ROI TISSUE STATISTICS:' in text and 'WHOLE TISSUE STATISTICS:' in text:
                inside_block = text.split('INSIDE ROI TISSUE STATISTICS:')[1].split('WHOLE TISSUE STATISTICS:')[0]
                whole_block = text.split('WHOLE TISSUE STATISTICS:')[1]
            else:
                inside_block = text
            parts = txt.parts
            batch = next((p for p in parts if p.lower().startswith('batch')), '')
            sex = 'Male' if any(p.lower()=='male' for p in parts) else ('Female' if any(p.lower()=='female' for p in parts) else '')
            row = {'batch': batch, 'sex': sex, 'filename': txt.name}
            for k,p in patterns.items():
                mi = p.search(inside_block)
                mw = p.search(whole_block)
                row[f'inside_{k}'] = mi.group(1) if mi else ''
                row[f'whole_{k}'] = mw.group(1) if mw else ''
            rows.append(row)
    return rows

try:
    import pandas as pd
    if DATA_CSV2.exists():
        master2 = pd.read_csv(DATA_CSV2)
    else:
        downloads_root = Path(r"c:\Users\hanss\Downloads\DEXA Scans (1)\DEXA Scans")
        rows2 = scan_and_build_week(downloads_root, 2)
        master2 = pd.DataFrame(rows2)
        try:
            master2.to_csv(DATA_CSV2, index=False)
        except Exception:
            pass
    if not master2.empty:
        df_batch2 = master2[master2['batch'].str.lower()==batch_name.lower()]
        if not df_batch2.empty:
            display(df_batch2.reset_index(drop=True))
        else:
            print('No week-2 rows for', batch_name)
    else:
        print('No week-2 files found anywhere')
except Exception as e:
    print('Error building/displaying week-2 table:', e)
# Out:
#      batch     sex    filename  inside_sample_area  whole_sample_area  \
# 0  Batch 2  Female  B2_F_0.txt              27.050             27.786
# 1  Batch 2  Female  B2_F_1.txt              31.724             33.039
# 2  Batch 2  Female  B2_F_2.txt              30.036             31.103
# 3  Batch 2  Female  B2_F_3.txt              23.334             26.209
# 4  Batch 2  Female  B2_F_4.txt              29.380             31.558
# 5  Batch 2    Male  B2_M_0.txt              29.459             29.723
# 6  Batch 2    Male  B2_M_1.txt              29.852             31.104
# 7  Batch 2    Male  B2_M_2.txt              30.322             30.519
# 8  Batch 2    Male  B2_M_3.txt              31.197             31.197
# 9  Batch 2    Male  B2_M_4.txt              27.668             28.581
#
#    inside_bone_area  whole_bone_area  inside_total_weight  whole_total_weight  \
# 0             8.711            8.953              24.6231             25.4822
# 1             9.095            9.468              30.4185             31.7259
# 2             9.140            9.435              27.5639             28.5957
# 3             7.471            9.231              26.2235             29.9516
# 4             9.724            9.923              28.4249             30.7161
# 5             9.247            9.359              29.5626             29.8956
# 6             9.304            9.524              31.5554             33.0026
# 7             8.197            8.243              29.7967             30.0148
# 8             8.858            8.858              32.2576             32.2576
# 9             8.831            9.086              28.0062             29.0568
#
#    inside_soft_weight  ...  inside_lean_weight  whole_lean_weight  \
# 0             24.0002  ...             15.6430            16.0854
# 1             29.7811  ...             19.8027            20.4816
# 2             26.9643  ...             16.2166            16.7334
# 3             25.7035  ...             17.1651            19.2559
# 4             27.7230  ...             14.4506            15.3962
# 5             28.8609  ...             21.8735            22.0509
# 6             30.8334  ...             22.5576            23.5050
# 7             29.2127  ...             20.3997            20.5540
# 8             31.6361  ...             22.4443            22.4443
# 9             27.3592  ...             20.2348            20.9440
#
#    inside_fat_weight  whole_fat_weight  inside_fat_percent  whole_fat_percent  \
# 0             8.3573            8.7504              34.822             35.233
# 1             9.9784           10.5676              33.506             34.035
# 2            10.7477           11.2407              39.859             40.182
# 3             8.5384            9.9004              33.219             33.956
# 4            13.2724           14.5981              47.875             48.670
# 5             6.9874            7.1310              24.211             24.436
# 6             8.2757            8.7593              26.840             27.149
# 7             8.8130            8.8734              30.168             30.154
# 8             9.1918            9.1918              29.055             29.055
# 9             7.1244            7.4438              26.040             26.222
#
#    inside_BMC  whole_BMC  inside_BMD  whole_BMD
# 0     0.62290    0.64646      71.504     72.207
# 1     0.63743    0.67679      70.082     71.484
# 2     0.59962    0.62168      65.601     65.893
# 3     0.51999    0.79529      69.604     86.152
# 4     0.70184    0.72181      72.174     72.744
# 5     0.70169    0.71372      75.885     76.265
# 6     0.72204    0.73828      77.609     77.515
# 7     0.58404    0.58735      71.252     71.255
# 8     0.62152    0.62152      70.163     70.163
# 9     0.64703    0.66897      73.272     73.625
#
# [10 rows x 21 columns]

# %% [markdown]
# ## Batch 2 — 3-week post-treatment summary

# %%
# Batch 2 — 3-week post-treatment summary
from pathlib import Path
import re

DATA_CSV3 = Path(r'../data/week3_reports.csv').resolve()
batch_name = 'Batch 2'

try:
    import pandas as pd
    if DATA_CSV3.exists():
        master3 = pd.read_csv(DATA_CSV3)
    else:
        downloads_root = Path(r"c:\Users\hanss\Downloads\DEXA Scans (1)\DEXA Scans")
        rows3 = scan_and_build_week(downloads_root, 3)
        master3 = pd.DataFrame(rows3)
        try:
            master3.to_csv(DATA_CSV3, index=False)
        except Exception:
            pass
    if not master3.empty:
        df_batch3 = master3[master3['batch'].str.lower()==batch_name.lower()]
        if not df_batch3.empty:
            display(df_batch3.reset_index(drop=True))
        else:
            print('No week-3 rows for', batch_name)
    else:
        print('No week-3 files found anywhere')
except Exception as e:
    print('Error building/displaying week-3 table:', e)
# Out:
#      batch     sex    filename  inside_sample_area  whole_sample_area  \
# 0  Batch 2  Female  B2_F_0.txt              27.736             29.971
# 1  Batch 2  Female  B2_F_1.txt              30.370             32.641
# 2  Batch 2  Female  B2_F_2.txt              29.205             31.574
# 3  Batch 2  Female  B2_F_4.txt              29.653             32.327
# 4  Batch 2    Male  B2_M_0.txt              29.018             32.241
# 5  Batch 2    Male  B2_M_1.txt              31.421             34.340
# 6  Batch 2    Male  B2_M_2.txt              29.901             32.738
# 7  Batch 2    Male  B2_M_3.txt              30.409             33.353
# 8  Batch 2    Male  B2_M_4.txt              28.142             31.037
#
#    inside_bone_area  whole_bone_area  inside_total_weight  whole_total_weight  \
# 0             8.836            9.948              25.0474             27.1984
# 1             9.148           10.347              31.1340             33.5920
# 2             9.193           10.411              28.0153             30.5018
# 3             9.091           10.467              30.2763             33.1094
# 4             9.564           11.354              29.9928             33.6346
# 5             9.544           11.052              32.3164             35.5604
# 6             8.198            9.640              31.0176             34.2940
# 7             8.703           10.015              30.8093             33.9877
# 8             8.676           10.162              28.4131             31.7375
#
#    inside_soft_weight  ...  inside_lean_weight  whole_lean_weight  \
# 0             24.3587  ...             16.4951            17.5472
# 1             30.4848  ...             20.6420            21.6707
# 2             27.3997  ...             17.1321            18.2799
# 3             29.6181  ...             17.7406            18.9051
# 4             29.1841  ...             22.9798            25.1828
# 5             31.5440  ...             24.3881            26.1773
# 6             30.4477  ...             21.9741            23.8324
# 7             30.2116  ...             21.8501            23.8090
# 8             27.7893  ...             21.6920            23.7581
#
#    inside_fat_weight  whole_fat_weight  inside_fat_percent  whole_fat_percent  \
# 0             7.8635            8.8165              32.282             33.442
# 1             9.8428           11.0842              32.287             33.840
# 2            10.2676           11.4427              37.474             38.498
# 3            11.8775           13.3456              40.102             41.381
# 4             6.2042            7.3650              21.259             22.628
# 5             7.1559            8.3831              22.686             24.256
# 6             8.4736            9.6847              27.830             28.895
# 7             8.3616            9.4026              27.677             28.311
# 8             6.0973            7.1434              21.941             23.117
#
#    inside_BMC  whole_BMC  inside_BMD  whole_BMD
# 0     0.68869    0.83464      77.942     83.900
# 1     0.64926    0.83717      70.973     80.906
# 2     0.61563    0.77923      66.971     74.844
# 3     0.65813    0.85871      72.394     82.037
# 4     0.80876    1.08673      84.563     95.717
# 5     0.77243    1.00002      80.936     90.482
# 6     0.56986    0.77687      69.512     80.591
# 7     0.59763    0.77598      68.672     77.480
# 8     0.62379    0.83608      71.903     82.277
#
# [9 rows x 21 columns]
